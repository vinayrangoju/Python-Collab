# %% [markdown]
# **Pandas**
#
# - `Pandas Library is used to Data Manipulation | Data cleaning `
#
# **Built_in_Functions_pandas**
#
# - `series `
# - `shape `
# - `size `
# - `loc `
# - `iloc `
# - `rename `
# - `drop `
# - `axis = 1`
# - `axis = 0`
# - `value_counts()`
# - `unique `
# - `groupby `
# - `concat`
# - `DataFrame`

# %%
import numpy as np
import pandas as pd

# %%
# series: 1D data -> pandas series -> into Excel format

a = np.array([10,7,13,21,19]) # 1D

b = pd.Series(a)

b
# Out:
# 0    10
# 1     7
# 2    13
# 3    21
# 4    19
# dtype: int64

# %%
b[2]
# Out:
# np.int64(13)

# %%
b.shape
# Out:
# (5,)

# %%
b
# Out:
# 0    10
# 1     7
# 2    13
# 3    21
# 4    19
# dtype: int64

# %%
b[1:4]
# Out:
# 1     7
# 2    13
# 3    21
# dtype: int64

# %%
# DataFrame: we can create number of rows and columns

a = {'Name':['John','Peter','Micheal','steve','Brad','Smith'] ,
     'Age':[30,42,29,27,33,31] ,
     'Location' : ['usa','india','uk','china','japan','sydney'],
     'company':['google','IBM','infosys','Meta','Wipro','MSFT'],
     'Salary':[1200,1400,900,560,1190,1400]

     }

b = pd.DataFrame(a , index = ['Row1','Row2','Row3','Row4','Row5','Row6'])
b
# Out:
#          Name  Age Location  company  Salary
# Row1     John   30      usa   google    1200
# Row2    Peter   42    india      IBM    1400
# Row3  Micheal   29       uk  infosys     900
# Row4    steve   27    china     Meta     560
# Row5     Brad   33    japan    Wipro    1190
# Row6    Smith   31   sydney     MSFT    1400

# %%
b['Location']['Row2']
# Out:
# 'india'

# %%
b.shape
# Out:
# (6, 5)

# %%
b.size
# Out:
# 30

# %%
b
# Out:
#          Name  Age Location  company  Salary
# Row1     John   30      usa   google    1200
# Row2    Peter   42    india      IBM    1400
# Row3  Micheal   29       uk  infosys     900
# Row4    steve   27    china     Meta     560
# Row5     Brad   33    japan    Wipro    1190
# Row6    Smith   31   sydney     MSFT    1400

# %%
# iloc = index and n-1

b.iloc[3:5 , 2:5]
# Out:
#      Location company  Salary
# Row4    china    Meta     560
# Row5    japan   Wipro    1190

# %%
# loc = no index and no n-1 logic
b.loc['Row4':'Row5' , 'Location':'Salary']
# Out:
#      Location company  Salary
# Row4    china    Meta     560
# Row5    japan   Wipro    1190

# %%
b.loc['Row2':'Row4' , 'Age':'company']
# Out:
#       Age Location  company
# Row2   42    india      IBM
# Row3   29       uk  infosys
# Row4   27    china     Meta

# %%
b.iloc[1:4  , 1:4]
# Out:
#       Age Location  company
# Row2   42    india      IBM
# Row3   29       uk  infosys
# Row4   27    china     Meta

# %%
b
# Out:
#          Name  Age Location  company  Salary
# Row1     John   30      usa   google    1200
# Row2    Peter   42    india      IBM    1400
# Row3  Micheal   29       uk  infosys     900
# Row4    steve   27    china     Meta     560
# Row5     Brad   33    japan    Wipro    1190
# Row6    Smith   31   sydney     MSFT    1400

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
b['Location']['Row5'] = 'Dubai'

# %%
b
# Out:
#          Name  Age Location  company  Salary
# Row1     John   30      usa   google    1200
# Row2    Peter   42    india      IBM    1400
# Row3  Micheal   29       uk  infosys     900
# Row4    steve   27    china     Meta     560
# Row5     Brad   33    Dubai    Wipro    1190
# Row6    Smith   31   sydney     MSFT    1400

# %%
b['EMI'] = [120,140,90,56,119,140]

# %%
b
# Out:
#          Name  Age Location  company  Salary  EMI
# Row1     John   30      usa   google    1200  120
# Row2    Peter   42    india      IBM    1400  140
# Row3  Micheal   29       uk  infosys     900   90
# Row4    steve   27    china     Meta     560   56
# Row5     Brad   33    Dubai    Wipro    1190  119
# Row6    Smith   31   sydney     MSFT    1400  140

# %%
# axis = 1 -> col
# axis = 0 -> row

# %%
b
# Out:
#          Name  Age Location  company  Salary  EMI
# Row1     John   30      usa   google    1200  120
# Row2    Peter   42    india      IBM    1400  140
# Row3  Micheal   29       uk  infosys     900   90
# Row4    steve   27    china     Meta     560   56
# Row5     Brad   33    Dubai    Wipro    1190  119
# Row6    Smith   31   sydney     MSFT    1400  140

# %%
b = b.drop(['company'],axis=1)

# %%
b
# Out:
#          Name  Age Location  Salary  EMI
# Row1     John   30      usa    1200  120
# Row2    Peter   42    india    1400  140
# Row3  Micheal   29       uk     900   90
# Row4    steve   27    china     560   56
# Row5     Brad   33    Dubai    1190  119
# Row6    Smith   31   sydney    1400  140

# %%
b = b.rename(columns={'Age':'Days'})

# %%
b
# Out:
#          Name  Days Location  Salary  EMI
# Row1     John    30      usa    1200  120
# Row2    Peter    42    india    1400  140
# Row3  Micheal    29       uk     900   90
# Row4    steve    27    china     560   56
# Row5     Brad    33    Dubai    1190  119
# Row6    Smith    31   sydney    1400  140

# %%
b['EMI'].mean()
# Out:
# np.float64(110.83333333333333)

# %%
b['EMI'].median()
# Out:
# 119.5

# %%
b['EMI'].mode()
# Out:
# 0    140
# Name: EMI, dtype: int64

# %%
b['EMI'].std()
# Out:
# 32.535621504232346

# %%
b['EMI'].var()
# Out:
# 1058.5666666666664

# %%
b.to_csv('Employee_details.csv',index = False)

# %%
a = np.random.rand(100,50)
c = pd.DataFrame(a)
c.to_csv('Random_data_client.csv',index= False)

# %%
c
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.831410  0.615543  0.669795  0.865940  0.474023  0.984564  0.993446
# 1   0.137435  0.835910  0.848917  0.661395  0.455513  0.287779  0.043214
# 2   0.985546  0.975971  0.203791  0.912315  0.229112  0.567647  0.967069
# 3   0.608784  0.079609  0.055432  0.136813  0.011096  0.495294  0.409401
# 4   0.914734  0.128026  0.227445  0.893232  0.809202  0.649114  0.958942
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.494343  0.993756  0.308620  0.480197  0.102503  0.559526  0.393956
# 96  0.983530  0.023309  0.975208  0.425704  0.294042  0.772592  0.095690
# 97  0.308188  0.694726  0.622999  0.733298  0.397425  0.565175  0.023660
# 98  0.973772  0.337366  0.664546  0.576888  0.254259  0.441225  0.807715
# 99  0.394323  0.277309  0.839018  0.164639  0.050744  0.593926  0.767695
#
#           7         8         9   ...        40        41        42        43  \
# ...

# %%
b
# Out:
#          Name  Days Location  Salary  EMI
# Row1     John    30      usa    1200  120
# Row2    Peter    42    india    1400  140
# Row3  Micheal    29       uk     900   90
# Row4    steve    27    china     560   56
# Row5     Brad    33    Dubai    1190  119
# Row6    Smith    31   sydney    1400  140

# %%
for i in b['EMI']:
  print(i)
# Out:
# 120
# 140
# 90
# 56
# 119
# 140

# %%
len(b['EMI'])
# Out:
# 6

# %%
c = 0
for i in b['EMI']:
  c = c + i

print(c / len(b['EMI']))
# Out:
# 110.83333333333333

# %%
b
# Out:
#          Name  Days Location  Salary  EMI
# Row1     John    30      usa    1200  120
# Row2    Peter    42    india    1400  140
# Row3  Micheal    29       uk     900   90
# Row4    steve    27    china     560   56
# Row5     Brad    33    Dubai    1190  119
# Row6    Smith    31   sydney    1400  140

# %%
b['PF'] = [10,20,np.nan,40,50,np.nan]

# %%
b
# Out:
#          Name  Days Location  Salary  EMI    PF
# Row1     John    30      usa    1200  120  10.0
# Row2    Peter    42    india    1400  140  20.0
# Row3  Micheal    29       uk     900   90   NaN
# Row4    steve    27    china     560   56  40.0
# Row5     Brad    33    Dubai    1190  119  50.0
# Row6    Smith    31   sydney    1400  140   NaN

# %%
b.to_csv('check.csv',index = True)

# %%
b['PF'] = b['PF'].fillna(100)

# %%
b
# Out:
#          Name  Days Location  Salary  EMI     PF
# Row1     John    30      usa    1200  120   10.0
# Row2    Peter    42    india    1400  140   20.0
# Row3  Micheal    29       uk     900   90  100.0
# Row4    steve    27    china     560   56   40.0
# Row5     Brad    33    Dubai    1190  119   50.0
# Row6    Smith    31   sydney    1400  140  100.0

# %%
b['Insurance'] = [10,20,np.nan,40,50,np.nan]

# %%
b
# Out:
#          Name  Days Location  Salary  EMI     PF  Insurance
# Row1     John    30      usa    1200  120   10.0       10.0
# Row2    Peter    42    india    1400  140   20.0       20.0
# Row3  Micheal    29       uk     900   90  100.0        NaN
# Row4    steve    27    china     560   56   40.0       40.0
# Row5     Brad    33    Dubai    1190  119   50.0       50.0
# Row6    Smith    31   sydney    1400  140  100.0        NaN

# %%
b = b.dropna()

# %%
b
# Out:
#        Name  Days Location  Salary  EMI    PF  Insurance
# Row1   John    30      usa    1200  120  10.0       10.0
# Row2  Peter    42    india    1400  140  20.0       20.0
# Row4  steve    27    china     560   56  40.0       40.0
# Row5   Brad    33    Dubai    1190  119  50.0       50.0

# %%
# read the data from exsheet

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/Titanic-Dataset.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head() # in df we have 891 rows -> head will show first 5 rows
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail() # tail will give last 5 rows
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.sample(3) # randomly out of 891 -> rows will come
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 284          285         0       1           Smith, Mr. Richard William
# 240          241         0       3                Zabour, Miss. Thamine
# 717          718         1       2  Troutt, Miss. Edwina Celia "Winnie"
#
#         Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 284    male   NaN      0      0  113056  26.0000   A19        S
# 240  female   NaN      1      0    2665  14.4542   NaN        C
# 717  female  27.0      0      0   34218  10.5000  E101        S

# %%
df = df.drop(['PassengerId','Name','Ticket'],axis=1)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
sum(df['Sex'] == 'male')
# Out:
# 577

# %%
sum(df['Sex'] == 'female')
# Out:
# 314

# %%
577 + 314
# Out:
# 891

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df.sample(5)
# Out:
#      Survived  Pclass   Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 164         0       3  male   1.0      4      1  39.6875   NaN        S
# 21          1       2  male  34.0      0      0  13.0000   D56        S
# 625         0       1  male  61.0      0      0  32.3208   D50        S
# 185         0       1  male   NaN      0      0  50.0000   A32        S
# 65          1       3  male   NaN      1      1  15.2458   NaN        C

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (183, 9)

# %%
df.sample(7)
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare        Cabin  \
# 268         1       1  female  58.0      0      1  153.4625         C125
# 96          0       1    male  71.0      0      0   34.6542           A5
# 587         1       1    male  60.0      1      1   79.2000          B41
# 27          0       1    male  19.0      3      2  263.0000  C23 C25 C27
# 248         1       1    male  37.0      1      1   52.5542          D35
# 340         1       2    male   2.0      1      1   26.0000           F2
# 867         0       1    male  31.0      0      0   50.4958          A24
#
#     Embarked
# 268        S
# 96         C
# 587        C
# 27         S
# 248        S
# 340        S
# 867        S

# %%
df.to_csv('titanic_cleaned_data.csv',index=False)

# %%
# concat

b
# Out:
#        Name  Days Location  Salary  EMI    PF  Insurance
# Row1   John    30      usa    1200  120  10.0       10.0
# Row2  Peter    42    india    1400  140  20.0       20.0
# Row4  steve    27    china     560   56  40.0       40.0
# Row5   Brad    33    Dubai    1190  119  50.0       50.0

# %%
b['Distance'] = [10,50,12,14]

# %%
b
# Out:
#        Name  Days Location  Salary  EMI    PF  Insurance  Distance
# Row1   John    30      usa    1200  120  10.0       10.0        10
# Row2  Peter    42    india    1400  140  20.0       20.0        50
# Row4  steve    27    china     560   56  40.0       40.0        12
# Row5   Brad    33    Dubai    1190  119  50.0       50.0        14

# %%
# lets check aboout concat

b
# Out:
#        Name  Days Location  Salary  EMI    PF  Insurance  Distance
# Row1   John    30      usa    1200  120  10.0       10.0        10
# Row2  Peter    42    india    1400  140  20.0       20.0        50
# Row4  steve    27    china     560   56  40.0       40.0        12
# Row5   Brad    33    Dubai    1190  119  50.0       50.0        14

# %%
k = pd.DataFrame({'travel':['Yes','No','Yes','No']})
k
# Out:
#   travel
# 0    Yes
# 1     No
# 2    Yes
# 3     No

# %%
final = pd.concat([b.set_index(k.index),k],ignore_index=True,axis=1)

# %%
final
# Out:
#        0   1      2     3    4     5     6   7    8
# 0   John  30    usa  1200  120  10.0  10.0  10  Yes
# 1  Peter  42  india  1400  140  20.0  20.0  50   No
# 2  steve  27  china   560   56  40.0  40.0  12  Yes
# 3   Brad  33  Dubai  1190  119  50.0  50.0  14   No

# %%
b
# Out:
#        Name  Days Location  Salary  EMI    PF  Insurance  Distance
# Row1   John    30      usa    1200  120  10.0       10.0        10
# Row2  Peter    42    india    1400  140  20.0       20.0        50
# Row4  steve    27    china     560   56  40.0       40.0        12
# Row5   Brad    33    Dubai    1190  119  50.0       50.0        14

# %%
# GroupBy

h = pd.DataFrame({'Animal':['Lion','Lion','Lion','Tiger','Tiger','Tiger'],
                  'Speed':[90,80,100,160,180,145]})

h
# Out:
#   Animal  Speed
# 0   Lion     90
# 1   Lion     80
# 2   Lion    100
# 3  Tiger    160
# 4  Tiger    180
# 5  Tiger    145

# %%
h.groupby(['Animal']).mean()
# Out:
#              Speed
# Animal
# Lion     90.000000
# Tiger   161.666667
