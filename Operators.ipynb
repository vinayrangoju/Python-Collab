# %% [markdown]
# **Python_Operators**
#
# - `+,-,*,/,//,%,=,==,!=,>,<,>=<=,**,pow`

# %%
10 + 20 + 30
# Out:
# 60

# %%
a = 10
b = 20
print(a+b)
# Out:
# 30

# %%
10 - 20
# Out:
# -10

# %%
5 * 6
# Out:
# 30

# %%
22 / 5
# Out:
# 4.4

# %%
22 // 5
# Out:
# 4

# %%
22 % 5
# Out:
# 2

# %%
27 % 4
# Out:
# 3

# %%
f = 25
print(f)
# Out:
# 25

# %%
10 == 10
# Out:
# True

# %%
10 == 14
# Out:
# False

# %%
10 > 8
# Out:
# True

# %%
10 < 15
# Out:
# True

# %%
10 != 15
# Out:
# True

# %%
10 >= 9
# Out:
# True

# %%
21 <= 19
# Out:
# False

# %%
32 >= 19
# Out:
# True

# %%
2 ** 5
# Out:
# 32

# %%
pow(2,5)
# Out:
# 32

# %%
pow(2,5,6)
# Out:
# 2

# %%
pow(2,5,6)
# Out:
# 2

# %%
import math

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
math.factorial(5)
# Out:
# 120

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
import math

# %%
math.log(10)
# Out:
# 2.302585092994046
